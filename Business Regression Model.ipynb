# %% [markdown]
# ## This is the Business Classification Regression Model

# %%
import numpy as np
import pandas as pd

# %%
AW_data = pd.read_csv('C:/Users/user/Downloads/AW_dataset.csv', sep=',', index_col=0)
AW_data.head()
# Out:
#    CustomerID Title  FirstName MiddleName LastName Suffix  \
# 0       11000   NaN        Jon          V     Yang    NaN
# 1       11001   NaN     Eugene          L    Huang    NaN
# 2       11002   NaN      Ruben        NaN   Torres    NaN
# 3       11003   NaN    Christy        NaN      Zhu    NaN
# 4       11004   NaN  Elizabeth        NaN  Johnson    NaN
#
#           AddressLine1 AddressLine2         City StateProvinceName    ...      \
# 0      3761 N. 14th St          NaN  Rockhampton        Queensland    ...
# 1           2243 W St.          NaN      Seaford          Victoria    ...
# 2     5844 Linden Land          NaN       Hobart          Tasmania    ...
# 3     1825 Village Pl.          NaN   North Ryde   New South Wales    ...
# 4  7553 Harness Circle          NaN   Wollongong   New South Wales    ...
#
#   MaritalStatus HomeOwnerFlag NumberCarsOwned NumberChildrenAtHome  \
# 0             M             1               0                    0
# 1             S             0               1                    3
# 2             M             1               1                    3
# 3             S             0               1                    0
# 4             S             1               4                    5
#
#   TotalChildren YearlyIncome AveMonthSpend CustomerAge  CustomerAgegr  \
# 0             2       137947            89          31  Between 25-45
# 1             3       101141           117          32  Between 25-45
# 2             3        91945           123          32  Between 25-45
# 3             0        86688            50          29  Between 25-45
# 4             5        92771            95          29  Between 25-45
#
#    BikeBuyer
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
#
# [5 rows x 27 columns]
